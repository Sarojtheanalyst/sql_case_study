# %%
#!pip install sqlalchemy
#!pip install pymysql
#!pip install cryptography

# %% [markdown]
# # change the password of the databases

# %%
# ALTER USER 'root'@'localhost' IDENTIFIED BY 'python123';

# %% [markdown]
# # read the csv files

# %%
import pandas as pd
df=pd.read_csv(r'R:\sipps_ss\ml_projects\rainfall.csv')

# %%
df.shape
# Out:
# (366, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            366 non-null    int64
#  1   pressure       366 non-null    float64
#  2   maxtemp        366 non-null    float64
#  3   temparature    366 non-null    float64
#  4   mintemp        366 non-null    float64
#  5   dewpoint       366 non-null    float64
#  6   humidity       366 non-null    int64
#  7   cloud          366 non-null    int64
#  8   rainfall       366 non-null    object
#  9   sunshine       366 non-null    float64
#  10  winddirection  365 non-null    float64
#  11  windspeed      365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
df.columns
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %%
cols=[]
for col in df.columns.tolist():
    cols.append(col.strip())

# %%
cols
# Out:
# ['day',
#  'pressure',
#  'maxtemp',
#  'temparature',
#  'mintemp',
#  'dewpoint',
#  'humidity',
#  'cloud',
#  'rainfall',
#  'sunshine',
#  'winddirection',
#  'windspeed']

# %%
df.columns=cols

# %%
df.rename(columns={'         winddirection':'winddirection'},inplace=True)

# %% [markdown]
# # Creating a engine to insert the data inti the database

# %%
# USER_NAME , PASSWORD , PORT , DATAbane name 

from sqlalchemy import create_engine

# %%
connection_string = "mysql+pymysql://root:python123@localhost:3306/office"

# %%
engine = create_engine(connection_string)

# %%
df.to_sql('weather_data', con=engine, if_exists='append', index=False)

print(" sucessfully insert the data into the dtaabases ")
# Out:
#  sucessfully insert the data into the dtaabases

# %%
df.head()
# Out:
#    day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0    1     1025.9     19.9         18.3     16.8      13.1         72      49
# 1    2     1022.0     21.7         18.9     17.2      15.6         81      83
# 2    3     1019.7     20.3         19.3     18.0      18.4         95      91
# 3    4     1018.9     22.3         20.6     19.1      18.8         90      88
# 4    5     1015.9     21.3         20.7     20.2      19.9         95      81
#
#   rainfall  sunshine  winddirection  windspeed
# 0      yes       9.3           80.0       26.3
# 1      yes       0.6           50.0       15.3
# 2      yes       0.0           40.0       14.2
# 3      yes       1.0           50.0       16.9
# 4      yes       0.0           40.0       13.7

# %%
df.shape
# Out:
# (366, 12)

# %%
import os
os.getcwd()
# Out:
# 'R:\\sipps_ss\\sql_uisng_p[ythons'
